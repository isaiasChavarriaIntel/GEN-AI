# %% [markdown]
# ### 📊 Unified LLM Architecture Table: Layers, Heads, and Design Focus
#
# | Family / Model | Estimated Size (Parameters) | Context Window (Short-Term Memory) | Layers (Depth) | Attention Heads (Parallelism) | Attention Mechanism Design Focus |
# | :--- | :--- | :--- | :--- | :--- | :--- |
# | **DistilBERT** | 66 Million | 512 tokens | **6** | **12** | Standard Full Attention Multi-Matrix |
# | **BERT-Base (Demo Model)** | 110 Million | 512 tokens | **12** | **12** | Standard Full Attention Multi-Matrix |
# | **Llama 3.1 (8B)** | 8.0 Billion | 128,000 tokens | **32** | **32** | Grouped-Query Attention (GQA) |
# | **Claude Sonnet 3.5 / 4.0** | 100B - 400B (Est.) | 200,000 tokens | **~80** | **~64** | Optimized for Massive Codebase Parsing |
# | **GPT-4 / GPT-5 (o1 series)** | 1.0 to 2.0+ Trillion (Est.) | 400,000+ tokens | **~96** | **~96 (per Expert)** | Mixture of Experts (MoE) & Adaptive Routing |
# | **Claude Opus 3.5 / 4.0** | 2.0 to 5.0 Trillion (Est.) | 1,000,000+ tokens | **~120** | **~128 (per Expert)** | Multi-Query / Mixture-of-Experts Hybrid |
